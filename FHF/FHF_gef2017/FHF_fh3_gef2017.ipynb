# %%
from __future__ import annotations

import sys
from pathlib import Path
import time

project_dir = Path.cwd()

# Modified .py files can be placed either in the same folder as this notebook
# or inside a subfolder named FHF_modified.
module_dir = project_dir
if not (module_dir / "FHF_runner.py").exists():
    candidate = project_dir / "FHF_modified"
    if (candidate / "FHF_runner.py").exists():
        module_dir = candidate

if str(module_dir) not in sys.path:
    sys.path.insert(0, str(module_dir))

import numpy as np
import pandas as pd
import torch
from IPython.display import display

from FHF_runner import Args, set_seed, run_fhf
from FHF_nf import load_clients_from_csv
from FHF_Client import Client

import warnings
warnings.filterwarnings("ignore", message=".*flash attention.*")

# %%
print("torch version:", torch.__version__)
print("device:", "cuda" if torch.cuda.is_available() else "cpu")
print("working directory:", project_dir)
print("module directory:", module_dir)
# Out:
# torch version: 2.3.1+cu118
# device: cuda
# working directory: E:\yjz\FHF\FHF_gef2017
# module directory: E:\yjz\FHF\FHF_gef2017

# %%
# -------------------------
# Parameter setup
# -------------------------
args = Args()
args.seed = 42
set_seed(args.seed, torch_num_threads=getattr(args, "torch_num_threads", 1))
args.device = "cuda" if torch.cuda.is_available() else "cpu"

args.csv_path = "E:/yjz/Datasets/GEFCOM2017/Gef2017_univarivate.csv" 
#"E:/yjz/Datasets/AusGrid2013/AusGrid2013_univariate.csv"
args.model_type = "lstm"
args.truncated = None
args.fh = 2
args.lags = 48
args.num_rounds = 100 + args.fh * 50

args.recon_method = [
    "bu",
    "mint_cov",
    "mint_shrinkage",
    "mint_ols",
    "mint_var",
    "wls_structure",
]

# -------------------------
# Early stopping settings
# -------------------------
args.early_stop_enabled = True
args.early_stop_tol = 1e-5
args.early_stop_metric = "avg_normalised_loss_delta"
args.min_rounds = 20 + args.fh * 50

# Logging / output format
args.verbose_rounds = True
args.print_every = 1
args.return_result = True

args
# Out:
# Args(csv_path='E:/yjz/Datasets/GEFCOM2017/Gef2017_univarivate.csv', partition_col='partition_id', series_col='unique_id', time_col='ds', target_col='y', truncated=None, lags=48, fh=2, test_ratio=0.2, batch_size=256, model_type='lstm', input_size=1, hidden_size=64, num_layers=2, dropout=0.1, c_in=1, d_model=128, n_heads=4, e_layers=3, device='cuda', num_rounds=200, local_epochs=1, lr=0.001, weight_decay=0.0, optimizer='adam', recon_method=['bu', 'mint_cov', 'mint_shrinkage', 'mint_ols', 'mint_var', 'wls_structure'], ridge=1e-06, td_eps=1e-08, seed=42, validate_p2p=True, p2p_atol=1e-08, torch_num_threads=1, early_stop_enabled=True, early_stop_tol=1e-05, early_stop_metric='avg_normalised_loss_delta', min_rounds=120, verbose_rounds=True, print_every=1, return_result=True)

# %%
# Optional quick data check before training
client_ids, cid2series_preview, cid2df_preview = load_clients_from_csv(
    csv_path=args.csv_path,
    partition_col=args.partition_col,
    series_col=args.series_col,
    time_col=args.time_col,
    target_col=args.target_col,
    lags=args.lags,
    fh=args.fh,
    truncated=args.truncated,
)

c = Client(client_ids[0], cid2series_preview[client_ids[0]], cid2df_preview[client_ids[0]], args)
c.prepare_data()

print("n_clients:", len(client_ids))
print("first client:", client_ids[0], cid2series_preview[client_ids[0]])
print("device:", c.device)
print("train samples:", c.num_train_samples(), "batches:", len(c.train_loader))
# Out:
# n_clients: 10
# first client: 0 Total
# device: cuda
# train samples: 99286 batches: 388

# %%
# -------------------------
# Run FHF
# -------------------------
result = run_fhf(args)

clients = result["clients"]
cloud = result["cloud"]
cid2series = result["cid2series"]
timings = result["timings"]
round_logs = result["round_logs"]
early_stop = result["early_stop"]

print("early_stop:", early_stop)
# Out:
# Loaded 10 clients.
# Recon methods: ['bu', 'mint_cov', 'mint_shrinkage', 'mint_ols', 'mint_var', 'wls_structure']
# [Round 1/200] avg_normalised_loss=0.0344461, avg_actual_loss=34445.2, delta=nan, stopped=False
# [Round 2/200] avg_normalised_loss=0.0257054, avg_actual_loss=25647, delta=0.00874071, stopped=False
# [Round 3/200] avg_normalised_loss=0.0182315, avg_actual_loss=18414.1, delta=0.00747391, stopped=False
# [Round 4/200] avg_normalised_loss=0.0154301, avg_actual_loss=15456.1, delta=0.00280139, stopped=False
# [Round 5/200] avg_normalised_loss=0.0138076, avg_actual_loss=12824.5, delta=0.00162252, stopped=False
# [Round 6/200] avg_normalised_loss=0.0133959, avg_actual_loss=11842, delta=0.000411679, stopped=False
# [Round 7/200] avg_normalised_loss=0.012313, avg_actual_loss=11216.3, delta=0.00108294, stopped=False
# [Round 8/200] avg_normalised_loss=0.0111998, avg_actual_loss=10624.5, delta=0.00111311, stopped=False
# [Round 9/200] avg_normalised_loss=0.010901, avg_actual_loss=9606.02, delta=0.00029884, stopped=False
# [Round 10/200] avg_normalised_loss=0.0101573, avg_actual_loss=8934.94, delta=0.000743677, stopped=False
# [Round 11/200] avg_normalised_loss=0.00984407, avg_actual_loss=8411.89, delta=0.000313254, stopped=False
# [Round 12/200] avg_normalised_loss=0.00965332, avg_actual_loss=7846.21, delta=0.000190746, stopped=False
# [Round 13/200] avg_normalised_loss=0.00939954, avg_actual_loss=7877.88, delta=0.000253787, stopped=False
# [Round 14/200] avg_normalised_loss=0.00897975, avg_actual_loss=7816.23, delta=0.000419788, stopped=False
# [Round 15/200] avg_normalised_loss=0.00890005, avg_actual_loss=7738.23, delta=7.96966e-05, stopped=False
# [Round 16/200] avg_normalised_loss=0.00872833, avg_actual_loss=7626.5, delta=0.000171723, stopped=False
# [Round 17/200] avg_normalised_loss=0.00845545, avg_actual_loss=8110.92, delta=0.000272881, stopped=False
# [Round 18/200] avg_normalised_loss=0.0086322, avg_actual_loss=7311.92, delta=0.000176755, stopped=False
# [Round 19/200] avg_normalised_loss=0.00819229, avg_actual_loss=7049.35, delta=0.000439909, stopped=False
# [Round 20/200] avg_normalised_loss=0.00813363, avg_actual_loss=6758.11, delta=5.86601e-05, stopped=False
# [Round 21/200] avg_normalised_loss=0.00807562, avg_actual_loss=6403.83, delta=5.80147e-05, stopped=False
# [Round 22/200] avg_normalised_loss=0.00796279, avg_actual_loss=6596.28, delta=0.000112834, stopped=False
# [Round 23/200] avg_normalised_loss=0.00780732, avg_actual_loss=6223.04, delta=0.000155466, stopped=False
# [Round 24/200] avg_normalised_loss=0.00768647, avg_actual_loss=6339.21, delta=0.000120853, stopped=False
# [Round 25/200] avg_normalised_loss=0.0078142, avg_actual_loss=6931.29, delta=0.000127735, stopped=False
# [Round 26/200] avg_normalised_loss=0.00790363, avg_actual_loss=6328.62, delta=8.94313e-05, stopped=False
# [Round 27/200] avg_normalised_loss=0.00760466, avg_actual_loss=6341.7, delta=0.000298973, stopped=False
# [Round 28/200] avg_normalised_loss=0.00748082, avg_actual_loss=6577.56, delta=0.000123842, stopped=False
# [Round 29/200] avg_normalised_loss=0.00744921, avg_actual_loss=6187.92, delta=3.16056e-05, stopped=False
# [Round 30/200] avg_normalised_loss=0.00739539, avg_actual_loss=6062.07, delta=5.3818e-05, stopped=False
# [Round 31/200] avg_normalised_loss=0.0071608, avg_actual_loss=6093.9, delta=0.000234589, stopped=False
# [Round 32/200] avg_normalised_loss=0.00710281, avg_actual_loss=5849.74, delta=5.79922e-05, stopped=False
# [Round 33/200] avg_normalised_loss=0.00708545, avg_actual_loss=5586.13, delta=1.73623e-05, stopped=False
# [Round 34/200] avg_normalised_loss=0.00710883, avg_actual_loss=5592.15, delta=2.33839e-05, stopped=False
# [Round 35/200] avg_normalised_loss=0.00697985, avg_actual_loss=5609.6, delta=0.000128989, stopped=False
# [Round 36/200] avg_normalised_loss=0.0069619, avg_actual_loss=5541.58, delta=1.79446e-05, stopped=False
# [Round 37/200] avg_normalised_loss=0.00696211, avg_actual_loss=6131.43, delta=2.05962e-07, stopped=False
# [Round 38/200] avg_normalised_loss=0.00692326, avg_actual_loss=5337.89, delta=3.88417e-05, stopped=False
# [Round 39/200] avg_normalised_loss=0.00679921, avg_actual_loss=5508.68, delta=0.000124055, stopped=False
# [Round 40/200] avg_normalised_loss=0.0069758, avg_actual_loss=6047.38, delta=0.000176595, stopped=False
# [Round 41/200] avg_normalised_loss=0.00665655, avg_actual_loss=5595.98, delta=0.000319258, stopped=False
# [Round 42/200] avg_normalised_loss=0.00682572, avg_actual_loss=5552.12, delta=0.00016917, stopped=False
# [Round 43/200] avg_normalised_loss=0.00665901, avg_actual_loss=5212.16, delta=0.000166712, stopped=False
# [Round 44/200] avg_normalised_loss=0.00688881, avg_actual_loss=5464.26, delta=0.000229808, stopped=False
# [Round 45/200] avg_normalised_loss=0.00648097, avg_actual_loss=5009.2, delta=0.000407848, stopped=False
# [Round 46/200] avg_normalised_loss=0.00667822, avg_actual_loss=5239.3, delta=0.000197255, stopped=False
# [Round 47/200] avg_normalised_loss=0.00676124, avg_actual_loss=5673.43, delta=8.30201e-05, stopped=False
# [Round 48/200] avg_normalised_loss=0.00634737, avg_actual_loss=4997.31, delta=0.000413869, stopped=False
# [Round 49/200] avg_normalised_loss=0.00653351, avg_actual_loss=5079.13, delta=0.000186138, stopped=False
# [Round 50/200] avg_normalised_loss=0.00634383, avg_actual_loss=5042.7, delta=0.000189682, stopped=False
# [Round 51/200] avg_normalised_loss=0.00639199, avg_actual_loss=4985.32, delta=4.81629e-05, stopped=False
# [Round 52/200] avg_normalised_loss=0.00634794, avg_actual_loss=4870.68, delta=4.40469e-05, stopped=False
# [Round 53/200] avg_normalised_loss=0.00633113, avg_actual_loss=5066.91, delta=1.68172e-05, stopped=False
# [Round 54/200] avg_normalised_loss=0.00625917, avg_actual_loss=4691.7, delta=7.19536e-05, stopped=False
# [Round 55/200] avg_normalised_loss=0.00630604, avg_actual_loss=5006.89, delta=4.68659e-05, stopped=False
# [Round 56/200] avg_normalised_loss=0.00631734, avg_actual_loss=4833.61, delta=1.13028e-05, stopped=False
# [Round 57/200] avg_normalised_loss=0.00612184, avg_actual_loss=4657.91, delta=0.0001955, stopped=False
# [Round 58/200] avg_normalised_loss=0.00611846, avg_actual_loss=4781.66, delta=3.37829e-06, stopped=False
# [Round 59/200] avg_normalised_loss=0.00629357, avg_actual_loss=4896.27, delta=0.000175111, stopped=False
# [Round 60/200] avg_normalised_loss=0.00608863, avg_actual_loss=4528.12, delta=0.000204946, stopped=False
# [Round 61/200] avg_normalised_loss=0.00612896, avg_actual_loss=4700.36, delta=4.03283e-05, stopped=False
# [Round 62/200] avg_normalised_loss=0.00613122, avg_actual_loss=5002.41, delta=2.2662e-06, stopped=False
# [Round 63/200] avg_normalised_loss=0.00612306, avg_actual_loss=5123.31, delta=8.1668e-06, stopped=False
# [Round 64/200] avg_normalised_loss=0.00597369, avg_actual_loss=4602.38, delta=0.000149364, stopped=False
# [Round 65/200] avg_normalised_loss=0.00598446, avg_actual_loss=4432.26, delta=1.07668e-05, stopped=False
# [Round 66/200] avg_normalised_loss=0.00595634, avg_actual_loss=4578.29, delta=2.81197e-05, stopped=False
# [Round 67/200] avg_normalised_loss=0.00596118, avg_actual_loss=4663, delta=4.84411e-06, stopped=False
# [Round 68/200] avg_normalised_loss=0.00589766, avg_actual_loss=4430.74, delta=6.35224e-05, stopped=False
# [Round 69/200] avg_normalised_loss=0.00580058, avg_actual_loss=4385.35, delta=9.70772e-05, stopped=False
# [Round 70/200] avg_normalised_loss=0.00582676, avg_actual_loss=4473.21, delta=2.61764e-05, stopped=False
# [Round 71/200] avg_normalised_loss=0.00579385, avg_actual_loss=4571.12, delta=3.29112e-05, stopped=False
# [Round 72/200] avg_normalised_loss=0.00578291, avg_actual_loss=4268.67, delta=1.09425e-05, stopped=False
# [Round 73/200] avg_normalised_loss=0.00573195, avg_actual_loss=4376.82, delta=5.09552e-05, stopped=False
# [Round 74/200] avg_normalised_loss=0.00577415, avg_actual_loss=4552.78, delta=4.22024e-05, stopped=False
# [Round 75/200] avg_normalised_loss=0.00580722, avg_actual_loss=4493.33, delta=3.30622e-05, stopped=False
# [Round 76/200] avg_normalised_loss=0.00573032, avg_actual_loss=4266.07, delta=7.68917e-05, stopped=False
# [Round 77/200] avg_normalised_loss=0.00570799, avg_actual_loss=4265.15, delta=2.23379e-05, stopped=False
# [Round 78/200] avg_normalised_loss=0.00566266, avg_actual_loss=4220.69, delta=4.53225e-05, stopped=False
# [Round 79/200] avg_normalised_loss=0.00589141, avg_actual_loss=4533.88, delta=0.00022875, stopped=False
# [Round 80/200] avg_normalised_loss=0.00559798, avg_actual_loss=4170.72, delta=0.000293437, stopped=False
# [Round 81/200] avg_normalised_loss=0.00568651, avg_actual_loss=4194.91, delta=8.85359e-05, stopped=False
# [Round 82/200] avg_normalised_loss=0.00563938, avg_actual_loss=4343.19, delta=4.71312e-05, stopped=False
# [Round 83/200] avg_normalised_loss=0.00563206, avg_actual_loss=4056.52, delta=7.31676e-06, stopped=False
# [Round 84/200] avg_normalised_loss=0.00553507, avg_actual_loss=4017.88, delta=9.69936e-05, stopped=False
# [Round 85/200] avg_normalised_loss=0.00561514, avg_actual_loss=4361.64, delta=8.00698e-05, stopped=False
# [Round 86/200] avg_normalised_loss=0.00549254, avg_actual_loss=4042.61, delta=0.000122601, stopped=False
# [Round 87/200] avg_normalised_loss=0.00554027, avg_actual_loss=4148.08, delta=4.7728e-05, stopped=False
# [Round 88/200] avg_normalised_loss=0.00547477, avg_actual_loss=4021.64, delta=6.54929e-05, stopped=False
# [Round 89/200] avg_normalised_loss=0.00554787, avg_actual_loss=4328.5, delta=7.30958e-05, stopped=False
# [Round 90/200] avg_normalised_loss=0.00541515, avg_actual_loss=3849.32, delta=0.000132717, stopped=False
# [Round 91/200] avg_normalised_loss=0.00548856, avg_actual_loss=3976.69, delta=7.34102e-05, stopped=False
# [Round 92/200] avg_normalised_loss=0.00542902, avg_actual_loss=3855.72, delta=5.95418e-05, stopped=False
# [Round 93/200] avg_normalised_loss=0.00541601, avg_actual_loss=3978.78, delta=1.30077e-05, stopped=False
# [Round 94/200] avg_normalised_loss=0.005429, avg_actual_loss=4068.49, delta=1.29918e-05, stopped=False
# [Round 95/200] avg_normalised_loss=0.00538179, avg_actual_loss=4023.93, delta=4.72128e-05, stopped=False
# [Round 96/200] avg_normalised_loss=0.00535546, avg_actual_loss=3944.57, delta=2.63359e-05, stopped=False
# [Round 97/200] avg_normalised_loss=0.00536481, avg_actual_loss=3997.98, delta=9.35218e-06, stopped=False
# [Round 98/200] avg_normalised_loss=0.00535377, avg_actual_loss=3855.87, delta=1.10351e-05, stopped=False
# [Round 99/200] avg_normalised_loss=0.00533039, avg_actual_loss=3867.03, delta=2.3385e-05, stopped=False
# [Round 100/200] avg_normalised_loss=0.00530497, avg_actual_loss=3902.73, delta=2.5423e-05, stopped=False
# [Round 101/200] avg_normalised_loss=0.00526986, avg_actual_loss=3913.84, delta=3.51044e-05, stopped=False
# [Round 102/200] avg_normalised_loss=0.00533753, avg_actual_loss=4194.55, delta=6.76724e-05, stopped=False
# [Round 103/200] avg_normalised_loss=0.00536086, avg_actual_loss=3878.49, delta=2.33246e-05, stopped=False
# [Round 104/200] avg_normalised_loss=0.00530807, avg_actual_loss=3860.5, delta=5.27865e-05, stopped=False
# [Round 105/200] avg_normalised_loss=0.00534283, avg_actual_loss=3929.01, delta=3.47566e-05, stopped=False
# [Round 106/200] avg_normalised_loss=0.00528079, avg_actual_loss=3910.69, delta=6.20402e-05, stopped=False
# [Round 107/200] avg_normalised_loss=0.00523315, avg_actual_loss=3931.09, delta=4.76367e-05, stopped=False
# [Round 108/200] avg_normalised_loss=0.00517742, avg_actual_loss=3979.03, delta=5.57336e-05, stopped=False
# [Round 109/200] avg_normalised_loss=0.0052623, avg_actual_loss=3905.46, delta=8.48785e-05, stopped=False
# [Round 110/200] avg_normalised_loss=0.0052137, avg_actual_loss=3910.43, delta=4.85934e-05, stopped=False
# [Round 111/200] avg_normalised_loss=0.00520262, avg_actual_loss=4027.73, delta=1.10837e-05, stopped=False
# [Round 112/200] avg_normalised_loss=0.00522402, avg_actual_loss=3908.62, delta=2.13967e-05, stopped=False
# [Round 113/200] avg_normalised_loss=0.00525593, avg_actual_loss=3760.83, delta=3.19159e-05, stopped=False
# [Round 114/200] avg_normalised_loss=0.00521062, avg_actual_loss=3781.77, delta=4.53134e-05, stopped=False
# [Round 115/200] avg_normalised_loss=0.00516581, avg_actual_loss=3749.93, delta=4.48122e-05, stopped=False
# [Round 116/200] avg_normalised_loss=0.00513479, avg_actual_loss=3739.73, delta=3.10143e-05, stopped=False
# [Round 117/200] avg_normalised_loss=0.00513749, avg_actual_loss=3890.37, delta=2.69834e-06, stopped=False
# [Round 118/200] avg_normalised_loss=0.00518803, avg_actual_loss=3682.38, delta=5.0542e-05, stopped=False
# [Round 119/200] avg_normalised_loss=0.00515404, avg_actual_loss=3768.96, delta=3.39913e-05, stopped=False
# [Round 120/200] avg_normalised_loss=0.00514295, avg_actual_loss=3864.3, delta=1.10936e-05, stopped=False
# [Round 121/200] avg_normalised_loss=0.00512957, avg_actual_loss=3737.52, delta=1.33723e-05, stopped=False
# [Round 122/200] avg_normalised_loss=0.00507033, avg_actual_loss=3628.93, delta=5.92438e-05, stopped=False
# [Round 123/200] avg_normalised_loss=0.00507915, avg_actual_loss=3756.85, delta=8.81921e-06, stopped=True
# [Early Stop] normalised loss delta 8.81921e-06 < 1e-05 at round 123
# early_stop: {'stopped_early': True, 'stop_reason': 'abs(avg_normalised_loss - previous_avg_normalised_loss) < 1e-05', 'stopped_round': 123, 'final_avg_normalised_loss': 0.005079149960954389, 'final_avg_actual_loss': 3756.8514720194894, 'final_normalised_loss_delta': 8.819212555100445e-06, 'final_avg_train_loss': 0.005079149960954389}

# %%
# Cloud-round training log
round_log_df = pd.DataFrame(round_logs)
round_log_df.tail()
# Out:
#      round  num_rounds  avg_normalised_loss  avg_actual_loss  \
# 118    119         200             0.005154      3768.964046
# 119    120         200             0.005143      3864.300329
# 120    121         200             0.005130      3737.520908
# 121    122         200             0.005070      3628.927446
# 122    123         200             0.005079      3756.851472
#
#      normalised_loss_delta  avg_train_loss  n_train_nodes  early_stop_enabled  \
# 118               0.000034        0.005154             10                True
# 119               0.000011        0.005143             10                True
# 120               0.000013        0.005130             10                True
# 121               0.000059        0.005070             10                True
# 122               0.000009        0.005079             10                True
#
#      early_stop_tol          early_stop_metric  stopped
# 118         0.00001  avg_normalised_loss_delta    False
# 119         0.00001  avg_normalised_loss_delta    False
# 120         0.00001  avg_normalised_loss_delta    False
# 121         0.00001  avg_normalised_loss_delta    False
# 122         0.00001  avg_normalised_loss_delta     True

# %%
# Check reconciled forecast methods and shapes
cid0 = list(clients.keys())[0]
print("client:", cid0, cid2series[cid0])
print("methods:", list(clients[cid0].reconciled_forecasts.keys()))

for method, arr in clients[cid0].reconciled_forecasts.items():
    print(method, np.asarray(arr).shape)
# Out:
# client: 0 Total
# methods: ['bu', 'mint_cov', 'mint_shrinkage', 'mint_ols', 'mint_var', 'wls_structure']
# bu (24835, 3)
# mint_cov (24835, 3)
# mint_shrinkage (24835, 3)
# mint_ols (24835, 3)
# mint_var (24835, 3)
# wls_structure (24835, 3)

# %% [markdown]
# ## Level-wise evaluation: MAE, MASE, RMSSE

# %%
def _as_2d(arr):
    arr = np.asarray(arr, dtype=np.float64)
    if arr.ndim == 1:
        arr = arr[:, None]
    return arr


def _target_cols(args):
    return ['y'] + [f'post_{i}' for i in range(1, int(args.fh) + 1)]


def split_node_df(df_one, args):
    time_col = getattr(args, 'time_col', 'ds')
    sub = df_one.sort_values(time_col).copy().reset_index(drop=True)

    n_windows = len(sub)
    n_raw = n_windows + int(args.lags) + int(args.fh)
    n_train_raw = int((1 - float(args.test_ratio)) * n_raw)
    n_train_windows = n_train_raw - int(args.lags) - int(args.fh)

    if n_train_windows <= 0 or n_train_windows >= n_windows:
        raise ValueError(
            f'Bad split: n_windows={n_windows}, n_train_windows={n_train_windows}'
        )

    return sub.iloc[:n_train_windows].copy(), sub.iloc[n_train_windows:].copy()


def make_naive_forecast(node, args):
    """Simple random-walk naive forecast: use the latest available lag, lags_1.

    For multi-step horizons, the same last observed value is repeated across
    horizons. This is the standard persistence baseline and uses no test future
    information.
    """
    _, ts_df = split_node_df(node.df, args)
    y_true = _as_2d(node.test_true)
    if 'lags_1' not in ts_df.columns:
        raise KeyError("Cannot compute naive forecast because 'lags_1' is missing.")
    naive_1d = ts_df['lags_1'].to_numpy(dtype=np.float64)
    if len(naive_1d) != y_true.shape[0]:
        raise ValueError(
            f'Naive length mismatch: naive={len(naive_1d)}, y_true={y_true.shape[0]}'
        )
    return np.repeat(naive_1d[:, None], y_true.shape[1], axis=1)


def _safe_scale_denominators(train_true, eps=1e-12):
    """Return MASE and RMSSE denominators from training true values only."""
    train_true = _as_2d(train_true)
    if train_true.shape[0] <= 1:
        return np.nan, np.nan

    diff = np.diff(train_true, axis=0)
    mase_denom = np.nanmean(np.abs(diff))
    rmsse_denom = np.nanmean(diff ** 2)

    if (not np.isfinite(mase_denom)) or mase_denom <= eps:
        mase_denom = np.nan
    if (not np.isfinite(rmsse_denom)) or rmsse_denom <= eps:
        rmsse_denom = np.nan

    return float(mase_denom), float(rmsse_denom)


def _role_from_level(level, min_level, max_level):
    if level == min_level:
        return 'top'
    if level == max_level:
        return 'bottom'
    return 'middle'


def compute_metrics_by_level(clients, cid2series, args, include_naive=True, eps=1e-12):
    rows = []

    levels = {
        int(cid): int(str(series).count('/') + 1)
        for cid, series in cid2series.items()
    }
    min_level = min(levels.values())
    max_level = max(levels.values())

    for cid in sorted(clients.keys()):
        node = clients[cid]
        unique_id = str(cid2series[cid])
        level = int(unique_id.count('/') + 1)
        role = _role_from_level(level, min_level, max_level)

        y_true = _as_2d(node.test_true)
        train_true = _as_2d(node.y2)
        mase_denom, rmsse_denom = _safe_scale_denominators(train_true, eps=eps)

        method_forecasts = {'base': node.base_forecast}
        if include_naive:
            method_forecasts['naive'] = make_naive_forecast(node, args)
        method_forecasts.update(node.reconciled_forecasts)

        for method, forecast in method_forecasts.items():
            y_pred = _as_2d(forecast)
            if y_pred.shape != y_true.shape:
                raise ValueError(
                    f'Shape mismatch for cid={cid}, method={method}: '
                    f'y_true={y_true.shape}, y_pred={y_pred.shape}'
                )

            error = y_true - y_pred
            mae = float(np.nanmean(np.abs(error)))
            mse = float(np.nanmean(error ** 2))
            mase = mae / mase_denom if np.isfinite(mase_denom) else np.nan
            rmsse = np.sqrt(mse / rmsse_denom) if np.isfinite(rmsse_denom) else np.nan

            rows.append({
                'node_id': int(cid),
                'unique_id': unique_id,
                'level': level,
                'role': role,
                'method': str(method),
                'MAE': mae,
                'MASE': float(mase) if np.isfinite(mase) else np.nan,
                'RMSSE': float(rmsse) if np.isfinite(rmsse) else np.nan,
            })

    per_node_metrics = pd.DataFrame(rows)

    metrics_by_level = (
        per_node_metrics
        .groupby(['level', 'role', 'method'], as_index=False)
        .agg(
            MAE=('MAE', 'mean'),
            MASE=('MASE', 'mean'),
            RMSSE=('RMSSE', 'mean'),
            n_nodes=('node_id', 'nunique'),
        )
        .sort_values(['level', 'method'])
        .reset_index(drop=True)
    )

    overall_metrics = (
        per_node_metrics
        .groupby(['method'], as_index=False)
        .agg(
            MAE=('MAE', 'mean'),
            MASE=('MASE', 'mean'),
            RMSSE=('RMSSE', 'mean'),
            n_nodes=('node_id', 'nunique'),
        )
        .sort_values(['method'])
        .reset_index(drop=True)
    )

    return per_node_metrics, metrics_by_level, overall_metrics


def build_forecast_table_fhf(clients, cid2series, args, include_naive=True):
    """Build a per-series forecast table with base, reconciled, and naive forecasts."""
    rows = []
    target_cols = _target_cols(args)
    time_col = getattr(args, 'time_col', 'ds')

    for cid in sorted(clients.keys()):
        node = clients[cid]
        _, ts_df = split_node_df(node.df, args)
        unique_id = str(cid2series[cid])
        y_true = _as_2d(node.test_true)
        base = _as_2d(node.base_forecast)
        naive = make_naive_forecast(node, args) if include_naive else None
        rec = {method: _as_2d(arr) for method, arr in node.reconciled_forecasts.items()}

        for h_idx, target_col in enumerate(target_cols):
            for t_idx, (_, row) in enumerate(ts_df.iterrows()):
                out = {
                    'node_id': int(cid),
                    'unique_id': unique_id,
                    'ds': row[time_col],
                    'horizon_index': int(h_idx),
                    'target_col': target_col,
                    'y_true': float(y_true[t_idx, h_idx]),
                    'base': float(base[t_idx, h_idx]),
                }
                if include_naive:
                    out['naive'] = float(naive[t_idx, h_idx])
                for method, arr in rec.items():
                    out[str(method)] = float(arr[t_idx, h_idx])
                rows.append(out)

    return pd.DataFrame(rows)


def make_timing_df(timings):
    ordered_modules = [
        'setup_sec',
        'data_preparation_sec',
        'model_server_initialization_sec',
        'fl_training_sec',
        'residual_collection_sec',
        'recon_matrix_sec',
        'p2p_reconcile_sec',
        'reconciliation_sec',
        'evaluation_sec',
        'total_sec',
    ]
    return pd.DataFrame(
        [{'module': key, 'seconds': timings.get(key, np.nan)} for key in ordered_modules]
    )


def save_fhf_outputs(output_prefix, clients, cid2series, args, per_node_metrics,
                     metrics_by_level, overall_metrics, round_logs, timings):
    """Save forecasts, per-series metrics, aggregate metrics, round logs, and time costs."""
    forecast_table = build_forecast_table_fhf(clients, cid2series, args, include_naive=True)
    timing_df = make_timing_df(timings)

    paths = {
        'forecasts': f'{output_prefix}_forecasts.csv',
        'per_node_metrics': f'{output_prefix}_per_node_metrics.csv',
        'metrics_by_level': f'{output_prefix}_metrics_by_level.csv',
        'overall_metrics': f'{output_prefix}_overall_metrics.csv',
        'round_logs': f'{output_prefix}_round_logs.csv',
        'timing': f'{output_prefix}_timing.csv',
    }

    forecast_table.to_csv(paths['forecasts'], index=False)
    per_node_metrics.to_csv(paths['per_node_metrics'], index=False)
    metrics_by_level.to_csv(paths['metrics_by_level'], index=False)
    overall_metrics.to_csv(paths['overall_metrics'], index=False)
    pd.DataFrame(round_logs).to_csv(paths['round_logs'], index=False)
    timing_df.to_csv(paths['timing'], index=False)

    return paths, forecast_table, timing_df


_eval_t0 = time.perf_counter()
per_node_metrics, metrics_by_level, overall_metrics = compute_metrics_by_level(
    clients, cid2series, args, include_naive=True
)
timings['evaluation_sec'] = time.perf_counter() - _eval_t0
timings['total_sec'] = (
    timings.get('setup_sec', 0.0)
    + timings.get('fl_training_sec', 0.0)
    + timings.get('reconciliation_sec', 0.0)
    + timings.get('evaluation_sec', 0.0)
)

output_prefix = f'fh{args.fh + 1}_FHF'
output_paths, forecast_table, timing_df = save_fhf_outputs(
    output_prefix=output_prefix,
    clients=clients,
    cid2series=cid2series,
    args=args,
    per_node_metrics=per_node_metrics,
    metrics_by_level=metrics_by_level,
    overall_metrics=overall_metrics,
    round_logs=round_logs,
    timings=timings,
)

result['timings'] = timings
result['per_node_metrics'] = per_node_metrics
result['metrics_by_level'] = metrics_by_level
result['overall_metrics'] = overall_metrics
result['forecast_table'] = forecast_table
result['output_paths'] = output_paths

print('Saved outputs:')
for name, path in output_paths.items():
    print(f'  {name}: {path}')

metrics_by_level
# Out:
# Saved outputs:
#   forecasts: fh3_FHF_forecasts.csv
#   per_node_metrics: fh3_FHF_per_node_metrics.csv
#   metrics_by_level: fh3_FHF_metrics_by_level.csv
#   overall_metrics: fh3_FHF_overall_metrics.csv
#   round_logs: fh3_FHF_round_logs.csv
#   timing: fh3_FHF_timing.csv
#     level    role          method          MAE      MASE     RMSSE  n_nodes
# 0       1     top            base   140.584847  0.243013  0.268033        1
# 1       1     top              bu   149.338010  0.258144  0.283924        1
# 2       1     top        mint_cov   140.925102  0.243601  0.268612        1
# 3       1     top        mint_ols   140.970302  0.243679  0.268874        1
# 4       1     top  mint_shrinkage   140.924856  0.243601  0.268611        1
# 5       1     top        mint_var   145.441385  0.251408  0.277063        1
# 6       1     top           naive  1015.955872  1.756167  1.803449        1
# 7       1     top   wls_structure   140.970300  0.243679  0.268874        1
# 8       2  middle            base    31.158822  0.356388  0.383796        6
# 9       2  middle              bu    31.556457  0.357916  0.385197        6
# 10      2  middle        mint_cov    30.495079  0.349457  0.374797        6
# 11      2  middle        mint_ols    30.948507  0.354424  0.377879        6
# 12      2  middle  mint_shrinkage    30.494994  0.349450  0.374787        6
# 13      2  middle        mint_var    31.016231  0.354488  0.381450        6
# 14      2  middle           naive   171.573563  1.761382  1.798557        6
# 15      2  middle   wls_structure    30.948504  0.354424  0.377879        6
# 16      3  bottom            base    32.437331  0.371417  0.410549        3
# 17      3  bottom              bu    32.437331  0.371417  0.410549        3
# 18      3  bottom        mint_cov    31.572419  0.362661  0.398564        3
# 19      3  bottom        mint_ols    31.899621  0.365489  0.402383        3
# 20      3  bottom  mint_shrinkage    31.571676  0.362652  0.398550        3
# 21      3  bottom        mint_var    31.995610  0.366794  0.404435        3
# 22      3  bottom           naive   154.145770  1.761955  1.804434        3
# 23      3  bottom   wls_structure    31.899615  0.365489  0.402383        3

# %%
# Optional overall average across all hierarchy nodes
overall_metrics
# Out:
#            method         MAE      MASE     RMSSE  n_nodes
# 0            base   42.484977  0.349559  0.380246       10
# 1              bu   43.598875  0.351989  0.382675       10
# 2        mint_cov   41.861283  0.342833  0.371308       10
# 3        mint_ols   42.236021  0.346669  0.374330       10
# 4  mint_shrinkage   41.860985  0.342826  0.371298       10
# 5        mint_var   42.752560  0.347872  0.377907       10
# 6           naive  250.783456  1.761032  1.800809       10
# 7   wls_structure   42.236017  0.346669  0.374330       10

# %% [markdown]
# ## Timing report

# %%
# Timing report saved by save_fhf_outputs(...).
timing_df
# Out:
#                             module      seconds
# 0                        setup_sec     9.087386
# 1             data_preparation_sec     9.081954
# 2  model_server_initialization_sec     0.005429
# 3                  fl_training_sec  5764.674927
# 4          residual_collection_sec    20.856436
# 5                 recon_matrix_sec     0.205422
# 6                p2p_reconcile_sec     0.529233
# 7               reconciliation_sec    21.591091
# 8                   evaluation_sec     1.120016
# 9                        total_sec  5796.473420

# %%
# Compact run summary
summary = {
    'stopped_early': result['stopped_early'],
    'stop_reason': result['stop_reason'],
    'stopped_round': result['stopped_round'],
    'final_avg_normalised_loss': result['final_avg_normalised_loss'],
    'final_avg_actual_loss': result['final_avg_actual_loss'],
    'final_normalised_loss_delta': result['final_normalised_loss_delta'],
    'n_clients': len(clients),
    'methods': list(clients[cid0].reconciled_forecasts.keys()),
    'output_paths': output_paths,
}
summary
# Out:
# {'stopped_early': True,
#  'stop_reason': 'abs(avg_normalised_loss - previous_avg_normalised_loss) < 1e-05',
#  'stopped_round': 123,
#  'final_avg_normalised_loss': 0.005079149960954389,
#  'final_avg_actual_loss': 3756.8514720194894,
#  'final_normalised_loss_delta': 8.819212555100445e-06,
#  'n_clients': 10,
#  'methods': ['bu',
#   'mint_cov',
#   'mint_shrinkage',
#   'mint_ols',
#   'mint_var',
#   'wls_structure'],
#  'output_paths': {'forecasts': 'fh3_FHF_forecasts.csv',
#   'per_node_metrics': 'fh3_FHF_per_node_metrics.csv',
#   'metrics_by_level': 'fh3_FHF_metrics_by_level.csv',
#   'overall_metrics': 'fh3_FHF_overall_metrics.csv',
#   'round_logs': 'fh3_FHF_round_logs.csv',
#   'timing': 'fh3_FHF_timing.csv'}}
